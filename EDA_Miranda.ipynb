# %% [markdown]
# # Intitial EDA

# %%
import pandas as pd 
import duckdb 

df = pd.read_csv("data_files/alvsjo_data.csv")
df
# Out:
#                         Namn          Typ               Kategori  \
# 0                     Marino   restaurant  Restaurang & Snabbmat
# 1    Hemköp Stockholm Älvsjö  supermarket               Matbutik
# 2                       OKQ8         fuel             Bensinmack
# 3                   Circle K         fuel             Bensinmack
# 4                 McDonald's    fast_food  Restaurang & Snabbmat
# ..                       ...          ...                    ...
# 540                 Lekplats   playground               Lekplats
# 541                 Lekplats   playground               Lekplats
# 542                 Lekplats   playground               Lekplats
# 543                 Lekplats   playground               Lekplats
# 544                 Lekplats   playground               Lekplats
#
#                     Gata   Nr        Lat        Lon
# 0             Klubbacken   51  59.305325  17.963290
# 1    Sjättenovembervägen  208  59.278752  18.002280
# 2                    NaN  NaN  59.294435  18.002588
# 3                    NaN  NaN  59.299954  18.012147
# 4                    NaN  NaN  59.293074  18.001211
# ..                   ...  ...        ...        ...
# 540                  NaN  NaN  59.303276  18.016878
# 541                  NaN  NaN  59.299426  18.001098
# 542                  NaN  NaN  59.291422  17.980889
# 543                  NaN  NaN  59.282429  17.975122
# 544                  NaN  NaN  59.307600  18.025908
#
# [545 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Namn      545 non-null    str
#  1   Typ       545 non-null    str
#  2   Kategori  544 non-null    str
#  3   Gata      115 non-null    str
#  4   Nr        110 non-null    str
#  5   Lat       545 non-null    float64
#  6   Lon       545 non-null    float64
# dtypes: float64(2), str(5)
# memory usage: 29.9 KB

# %%
df.dtypes 

# This gives the insight on the data types - and also makes me question why  nr  is str?
# Out:
# Namn            str
# Typ             str
# Kategori        str
# Gata            str
# Nr              str
# Lat         float64
# Lon         float64
# dtype: object

# %%
df.describe()
# Out:
#               Lat         Lon
# count  545.000000  545.000000
# mean    59.296407   17.996263
# std      0.011657    0.022851
# min     59.264781   17.943174
# 25%     59.286200   17.976784
# 50%     59.298668   18.000730
# 75%     59.305760   18.012823
# max     59.316601   18.037330

# %%
# T stands for transpose: rows  <-> cols (switch places)
df.describe().T
# Out:
#      count       mean       std        min        25%        50%        75%  \
# Lat  545.0  59.296407  0.011657  59.264781  59.286200  59.298668  59.305760
# Lon  545.0  17.996263  0.022851  17.943174  17.976784  18.000730  18.012823
#
#            max
# Lat  59.316601
# Lon  18.037330

# %% [markdown]
# ### Rows & Columns

# %%
df.columns
# Out:
# Index(['Namn', 'Typ', 'Kategori', 'Gata', 'Nr', 'Lat', 'Lon'], dtype='str')

# %%
len(df.columns)
# Out:
# 7

# %%
df.index
# Out:
# RangeIndex(start=0, stop=545, step=1)

# %%
#Adding 1 because it doesnt count row 0 
len(df.index) + 1
# Out:
# 546

# %% [markdown]
# ### Check for missing or Null values

# %%
duckdb.sql("""--sql 
    select *
    from df 
    where 
        namn IS NULL OR 
        typ IS NULL OR
        kategori IS NULL OR
        gata IS NULL OR
        nr IS NULL OR 
        lat IS NULL OR
        lon IS NULL
           
""").df()
# Out:
#            Namn         Typ               Kategori Gata   Nr        Lat  \
# 0          OKQ8        fuel             Bensinmack  NaN  NaN  59.294435
# 1      Circle K        fuel             Bensinmack  NaN  NaN  59.299954
# 2    McDonald's   fast_food  Restaurang & Snabbmat  NaN  NaN  59.293074
# 3     Sushi Bar  restaurant  Restaurang & Snabbmat  NaN  NaN  59.292424
# 4      Lekplats  playground               Lekplats  NaN  NaN  59.264781
# ..          ...         ...                    ...  ...  ...        ...
# 431    Lekplats  playground               Lekplats  NaN  NaN  59.303276
# 432    Lekplats  playground               Lekplats  NaN  NaN  59.299426
# 433    Lekplats  playground               Lekplats  NaN  NaN  59.291422
# 434    Lekplats  playground               Lekplats  NaN  NaN  59.282429
# 435    Lekplats  playground               Lekplats  NaN  NaN  59.307600
#
#            Lon
# 0    18.002588
# 1    18.012147
# 2    18.001211
# 3    17.967934
# 4    17.984072
# ..         ...
# 431  18.016878
# 432  18.001098
# 433  17.980889
# 434  17.975122
# 435  18.025908
#
# [436 rows x 7 columns]

# %%
duckdb.sql("""--sql 
    SELECT
        COUNT(*) - COUNT(namn)     AS namn_nulls,
        COUNT(*) - COUNT(typ)      AS typ_nulls,
        COUNT(*) - COUNT(kategori) AS kategori_nulls,
        COUNT(*) - COUNT(gata)     AS gata_nulls,
        COUNT(*) - COUNT(nr)       AS nr_nulls,
        COUNT(*) - COUNT(lat)      AS lat_nulls,
        COUNT(*) - COUNT(lon)      AS lon_nulls
    FROM df
""").df()
# Out:
#    namn_nulls  typ_nulls  kategori_nulls  gata_nulls  nr_nulls  lat_nulls  \
# 0           0          0               1         430       435          0
#
#    lon_nulls
# 0          0

# %% [markdown]
# ### Unique values in typ & kategori

# %%
len(df.Kategori.unique())
# Out:
# 15

# %%
len(df.Typ.unique())
# Out:
# 17

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Length: 545, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                         Namn          Typ               Kategori  \
# 0                     Marino   restaurant  Restaurang & Snabbmat
# 1    Hemköp Stockholm Älvsjö  supermarket               Matbutik
# 2                       OKQ8         fuel             Bensinmack
# 3                   Circle K         fuel             Bensinmack
# 4                 McDonald's    fast_food  Restaurang & Snabbmat
# ..                       ...          ...                    ...
# 540                 Lekplats   playground               Lekplats
# 541                 Lekplats   playground               Lekplats
# 542                 Lekplats   playground               Lekplats
# 543                 Lekplats   playground               Lekplats
# 544                 Lekplats   playground               Lekplats
#
#                     Gata   Nr        Lat        Lon
# 0             Klubbacken   51  59.305325  17.963290
# 1    Sjättenovembervägen  208  59.278752  18.002280
# 2                    NaN  NaN  59.294435  18.002588
# 3                    NaN  NaN  59.299954  18.012147
# 4                    NaN  NaN  59.293074  18.001211
# ..                   ...  ...        ...        ...
# 540                  NaN  NaN  59.303276  18.016878
# 541                  NaN  NaN  59.299426  18.001098
# 542                  NaN  NaN  59.291422  17.980889
# 543                  NaN  NaN  59.282429  17.975122
# 544                  NaN  NaN  59.307600  18.025908
#
# [545 rows x 7 columns]

# %% [markdown]
# ### Check categories

# %%
df['Kategori'].value_counts()
# Out:
# Kategori
# Restaurang & Snabbmat    192
# Lekplats                 186
# Kafé                      40
# Gym/Utomhusgym            36
# Matbutik                  26
# Tandläkare                15
# Apotek                    11
# Bensinmack                 9
# Trafikskola                8
# Vårdcentral                7
# Bibliotek                  6
# Systembolag                4
# Biograf                    3
# Fysioterapeut              1
# Name: count, dtype: int64

# %%
ax = df['Kategori'].value_counts().plot(
    kind='bar', color='teal', edgecolor='none')
ax.set_title("Antal service & butiker I Älvsjö-Hägersten")
ax.set_ylabel("Antal")
ax.set_xlabel("Kategori")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)  # Tar bort högerramen

# %%
# Out:
# Text(24.000000000000007, 0.5, 'Antal poster')
