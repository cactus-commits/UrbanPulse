# %%
import pandas as pd

crime_df = pd.read_excel(r'data_files\brottstatistik_bromma_hägersten-älvsjö.xlsx')

crime_df.head(25)
# Out:
#                        Anmälda brott Unnamed: 1 Brottsförebyggande rådet  \
# 0                                NaN        NaN                      NaN
# 1                                NaN       2025                     2025
# 2                                NaN        Jan                      Feb
# 3                                NaN      Antal                    Antal
# 4     Stadsdelsområde Bromma (Sthlm)        NaN                      NaN
# 5                 Totalt antal brott        924                      784
# 6          3-7 kap. Brott mot person        NaN                      NaN
# 7     3 kap. Brott mot liv och hälsa         43                       29
# 8          3-7 kap. Brott mot person        NaN                      NaN
# 9   4 kap. Brott mot frihet och frid         97                       77
# 10         3-7 kap. Brott mot person        NaN                      NaN
# 11         5 kap. Ärekränkningsbrott          4                        3
# ...

# %%
import pandas as pd

crime_bromma_df = pd.read_excel(r'data_files\brottstatistik_bromma_hägersten-älvsjö.xlsx')
crime_bromma_df = crime_bromma_df.iloc[[5, 7, 9, 11, 13, 15, 17, 20, 23, 26, 28, 30, 32, 33, 34]]
crime_bromma_df.columns = ['Anmälda brott', 'Jan', 'Feb', 'Mar', 'Apr', 'Maj', 'Jun', 'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar']

crime_bromma_df
# Out:
#                             Anmälda brott  Jan  Feb   Mar  Apr  Maj  Jun  Jul  \
# 5                      Totalt antal brott  924  784  1001  867  942  903  802
# 7          3 kap. Brott mot liv och hälsa   43   29    43   54   59   48   51
# 9        4 kap. Brott mot frihet och frid   97   77    92  106  138   80   97
# 11              5 kap. Ärekränkningsbrott    4    3     9    5    4    9   18
# 13                     6 kap. Sexualbrott   13    3    15    6   33   28   13
# 15                7 kap. Brott mot familj    1    1     1    0    2    0    0
# 17                 8 kap. Stöld, rån m.m.  237  174   233  210  232  232  203
# 20                     därav biltillgrepp    5    4     8    5    8    2    4
# 23           därav inbrottsstöld i bostad   18   10    13    7    8   15    7
# 26                 därav rån, inkl. grovt    1    4     1    0    4    2    3
# 28  9 kap. Bedrägeri och annan oredlighet  143  125   132   93   71  123   85
# ...

# %%
import pandas as pd

crime_hägersten_älvsjö_df = pd.read_excel(r'data_files\brottstatistik_bromma_hägersten-älvsjö.xlsx')
crime_hägersten_älvsjö_df = crime_hägersten_älvsjö_df.iloc[[36, 38, 40, 42, 44, 46, 48, 51, 54, 57, 59, 61, 63, 64, 65]]
crime_hägersten_älvsjö_df.columns = ['Anmälda brott', 'Jan', 'Feb', 'Mar', 'Apr', 'Maj', 'Jun', 'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar']
crime_hägersten_älvsjö_df['Stadsdel'] = 'Hägersten-Älvsjö'

crime_hägersten_älvsjö_df
# Out:
#                             Anmälda brott   Jan   Feb   Mar   Apr   Maj   Jun  \
# 36                     Totalt antal brott  1311  1253  1495  1524  1820  1508
# 38         3 kap. Brott mot liv och hälsa    90    64   110    71   103    91
# 40       4 kap. Brott mot frihet och frid   166   130   180   142   177   171
# 42              5 kap. Ärekränkningsbrott     9     5    11     8    13     9
# 44                     6 kap. Sexualbrott    17    22    15    22   121    13
# 46                7 kap. Brott mot familj     2     1     0     1     2     1
# 48                 8 kap. Stöld, rån m.m.   251   223   310   300   336   311
# 51                     därav biltillgrepp     6    11     2     1     6     4
# 54           därav inbrottsstöld i bostad    10     4     7     4     6     6
# 57                 därav rån, inkl. grovt     7     5     7     5     5     4
# 59  9 kap. Bedrägeri och annan oredlighet   176   232   207   229   301   184
# ...

# %%
import pandas as pd

crime_merged_df = pd.concat([crime_bromma_df, crime_hägersten_älvsjö_df], axis=0)

crime_merged_df['Anmälda brott'].str.strip()

crime_merged_df.replace({
    '3 kap. Brott mot liv och hälsa': 'Brott mot liv och hälsa',
    '4 kap. Brott mot frihet och frid': 'Brott mot frihet och frid',
    '5 kap. Ärekränkningsbrott': 'Ärekränkningsbrott',
    '6 kap. Sexualbrott': 'Sexualbrott',
    '7 kap. Brott mot familj': 'Brott mot familj',
    '8 kap. Stöld, rån m.m.': 'Stöld, rån m.m.',
    'därav biltillgrepp': 'Bilstöld',
    'därav inbrottsstöld i bostad': 'Inbrottsstöld i bostad',
    'därav rån, inkl. grovt': 'Rån',
    '9 kap. Bedrägeri och annan oredlighet': 'Bedrägeri och annan oredlighet',
    '12 kap. Skadegörelsebrott': 'Skadegörelsebrott',
    '13 kap. Allmänfarliga brott': 'Allmänfarliga brott'


}, inplace=True)

crime_merged_df
# Out:
# C:\Users\kalle\AppData\Local\Temp\ipykernel_15004\2620324450.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   crime_merged_df.replace({
#                      Anmälda brott   Jan   Feb   Mar   Apr   Maj   Jun   Jul  \
# 5               Totalt antal brott   924   784  1001   867   942   903   802
# 7          Brott mot liv och hälsa    43    29    43    54    59    48    51
# 9        Brott mot frihet och frid    97    77    92   106   138    80    97
# 11              Ärekränkningsbrott     4     3     9     5     4     9    18
# 13                     Sexualbrott    13     3    15     6    33    28    13
# 15                Brott mot familj     1     1     1     0     2     0     0
# ...
