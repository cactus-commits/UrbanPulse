# %%
import pandas as pd 

import pandas as pd

df = pd.read_csv("alvsjo_data.csv")

df
# Out:
#                         Namn          Typ    Kategori                 Gata  \
# 0                  Konstfack   university       Skola     LM Ericssons Väg
# 1                     Marino   restaurant  Restaurang           Klubbacken
# 2    Hemköp Stockholm Älvsjö  supermarket    Matbutik  Sjättenovembervägen
# 3                        NaN      parking   Parkering                  NaN
# 4                 McDonald's    fast_food    Snabbmat                  NaN
# ..                       ...          ...         ...                  ...
# 820                      NaN      parking   Parkering                  NaN
# 821                      NaN      parking   Parkering                  NaN
# 822          Aspuddens skola       school       Skola   Blommensbergsvägen
# 823                      NaN      parking   Parkering                  NaN
# 824                      NaN      parking   Parkering                  NaN
#
#       Nr        Lat        Lon
# 0     14  59.299773  17.994210
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Namn      450 non-null    str
#  1   Typ       825 non-null    str
#  2   Kategori  825 non-null    str
#  3   Gata      135 non-null    str
#  4   Nr        131 non-null    str
#  5   Lat       825 non-null    float64
#  6   Lon       825 non-null    float64
# dtypes: float64(2), str(5)
# memory usage: 45.2 KB

# %%
df.columns
# Out:
# Index(['Namn', 'Typ', 'Kategori', 'Gata', 'Nr', 'Lat', 'Lon'], dtype='str')

# %%
df.describe()
# Out:
#               Lat         Lon
# count  825.000000  825.000000
# mean    59.294621   17.994793
# std      0.011368    0.023371
# min     59.264904   17.942848
# 25%     59.285472   17.974856
# 50%     59.294183   17.999042
# 75%     59.304445   18.012308
# max     59.317949   18.036724

# %%
# T stands for transpose: rows  <-> cols (switch places)
df.describe().T
# Out:
#      count       mean       std        min        25%        50%        75%  \
# Lat  825.0  59.294621  0.011368  59.264904  59.285472  59.294183  59.304445
# Lon  825.0  17.994793  0.023371  17.942848  17.974856  17.999042  18.012308
#
#            max
# Lat  59.317949
# Lon  18.036724
